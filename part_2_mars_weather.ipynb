# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
## Scrape the website
html = browser.html
# Create a Beautiful Soup object
soup = BeautifulSoup(html, 'html.parser')

# %%
# Extract all rows of data
all_rows = soup.find_all('tr', class_='data-row')
all_rows
# Out:
# [<tr class="data-row">
#  <td>2</td>
#  <td>2012-08-16</td>
#  <td>10</td>
#  <td>155</td>
#  <td>6</td>
#  <td>-75.0</td>
#  <td>739.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>13</td>
#  <td>2012-08-17</td>
#  <td>11</td>
#  <td>156</td>
#  <td>6</td>
#  <td>-76.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>24</td>
#  <td>2012-08-18</td>
#  <td>12</td>
#  <td>156</td>
#  <td>6</td>
#  <td>-76.0</td>
#  <td>741.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>35</td>
#  <td>2012-08-19</td>
#  <td>13</td>
#  <td>157</td>
#  <td>6</td>
#  <td>-74.0</td>
#  <td>732.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>46</td>
#  <td>2012-08-20</td>
#  <td>14</td>
#  <td>157</td>
#  <td>6</td>
#  <td>-74.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>57</td>
#  <td>2012-08-21</td>
#  <td>15</td>
#  <td>158</td>
#  <td>6</td>
#  <td>-78.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>68</td>
#  <td>2012-08-22</td>
# ...

# %%
print(len(all_rows))
# Out:
# 1867

# %%
onedata = all_rows[0]
oneitem = onedata.find('td').text
print(oneitem)
# Out:
# 2

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
mars_data = []
# Loop through the scraped data to create a list of rows
for data in all_rows:
    oneitem = data.find_all('td')
    mars_td_data = {
        "id": oneitem[0].text,
        "terrestrial_date": oneitem[1].text,
        "sol":oneitem[2].text,
        "ls":oneitem[3].text,
        "month": oneitem[4].text,
        "min_temp": oneitem[5].text,
        "pressure": oneitem[6].text
    }
    mars_data.append(mars_td_data)  
    
print(mars_data)
# Out:
# [{'id': '2', 'terrestrial_date': '2012-08-16', 'sol': '10', 'ls': '155', 'month': '6', 'min_temp': '-75.0', 'pressure': '739.0'}, {'id': '13', 'terrestrial_date': '2012-08-17', 'sol': '11', 'ls': '156', 'month': '6', 'min_temp': '-76.0', 'pressure': '740.0'}, {'id': '24', 'terrestrial_date': '2012-08-18', 'sol': '12', 'ls': '156', 'month': '6', 'min_temp': '-76.0', 'pressure': '741.0'}, {'id': '35', 'terrestrial_date': '2012-08-19', 'sol': '13', 'ls': '157', 'month': '6', 'min_temp': '-74.0', 'pressure': '732.0'}, {'id': '46', 'terrestrial_date': '2012-08-20', 'sol': '14', 'ls': '157', 'month': '6', 'min_temp': '-74.0', 'pressure': '740.0'}, {'id': '57', 'terrestrial_date': '2012-08-21', 'sol': '15', 'ls': '158', 'month': '6', 'min_temp': '-78.0', 'pressure': '740.0'}, {'id': '68', 'terrestrial_date': '2012-08-22', 'sol': '16', 'ls': '158', 'month': '6', 'min_temp': '-77.0', 'pressure': '740.0'}, {'id': '79', 'terrestrial_date': '2012-08-23', 'sol': '17', 'ls': '159', 'month': '6', '
# ...

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
df = pd.DataFrame(mars_data)
df
# Out:
#         id terrestrial_date   sol   ls month min_temp pressure
# 0        2       2012-08-16    10  155     6    -75.0    739.0
# 1       13       2012-08-17    11  156     6    -76.0    740.0
# 2       24       2012-08-18    12  156     6    -76.0    741.0
# 3       35       2012-08-19    13  157     6    -74.0    732.0
# 4       46       2012-08-20    14  157     6    -74.0    740.0
# ...    ...              ...   ...  ...   ...      ...      ...
# 1862  1889       2018-02-23  1973  133     5    -78.0    730.0
# 1863  1892       2018-02-24  1974  134     5    -77.0    729.0
# 1864  1894       2018-02-25  1975  134     5    -76.0    729.0
# 1865  1893       2018-02-26  1976  135     5    -77.0    728.0
# 1866  1895       2018-02-27  1977  135     5    -77.0    727.0
#
# [1867 rows x 7 columns]

# %%
# Confirm DataFrame was created successfully
df.head()
# Out:
#    id terrestrial_date sol   ls month min_temp pressure
# 0   2       2012-08-16  10  155     6    -75.0    739.0
# 1  13       2012-08-17  11  156     6    -76.0    740.0
# 2  24       2012-08-18  12  156     6    -76.0    741.0
# 3  35       2012-08-19  13  157     6    -74.0    732.0
# 4  46       2012-08-20  14  157     6    -74.0    740.0

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
df.dtypes
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis
df['terrestrial_date'] = pd.to_datetime(df['terrestrial_date'])
df['sol'] = pd.to_numeric(df["sol"])
df['ls'] = pd.to_numeric(df["ls"])
df['month'] = pd.to_numeric(df["month"])
df = df.astype({'min_temp':'float64', 'pressure':'float64'})

# %%
# Confirm type changes were successful by examining data types again
df.dtypes
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                          int64
# ls                           int64
# month                        int64
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
total = df.groupby(df['month']).count()
total = total.reset_index()

total_count = total['id']
months = total['month']

result = {
    "month": months,
    "total": total_count
}

df2 = pd.DataFrame(result)
df2.set_index(df2['month'], inplace=True)

df2.drop(['month'], axis=1)
df2
# Out:
#        month  total
# month
# 1          1    174
# 2          2    178
# 3          3    192
# 4          4    194
# 5          5    149
# 6          6    147
# 7          7    142
# 8          8    141
# 9          9    134
# 10        10    112
# 11        11    138
# 12        12    166

# %%
# 1. How many data/months are there on Mars?
total = df.groupby('month')['month'].count()
total
# Out:
# month
# 1     174
# 2     178
# 3     192
# 4     194
# 5     149
# 6     147
# 7     142
# 8     141
# 9     134
# 10    112
# 11    138
# 12    166
# Name: month, dtype: int64

# %%
# 2. How many Martian days' worth of data are there?
total_days = df['month'].count()
total_days
# Out:
# 1867

# %%
# 3. What is the average low temperature by month?
avg_temp = df.groupby(['month'])['min_temp'].mean()
avg_temp
# Out:
# month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: min_temp, dtype: float64

# %%
# Plot the average pressure by month
avg_pressure = df.groupby('month')['pressure'].mean()


# avg_pressure.plot.bar(xlabel = "months", ylabel = "Atmospheric Pressure")

pressure_graph = avg_pressure.plot(kind = "bar")
pressure_graph.set_xlabel("month")
pressure_graph.set_ylabel("Atmospheric Pressure")

plt.show()

# %%
monthly_temp = avg_temp.sort_values(ascending = False)
monthly_temp
# Out:
# month
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 7    -72.281690
# 12   -74.451807
# 6    -75.299320
# 1    -77.160920
# 5    -79.308725
# 2    -79.932584
# 4    -82.747423
# 3    -83.307292
# Name: min_temp, dtype: float64

# %%
# Identify the coldest and hottest months in Curiosity's location
monthly_graph = monthly_temp.plot(kind = "bar")
monthly_graph.set_xlabel("month")
monthly_graph.set_ylabel("Temperature in Celsius")

plt.show()

# %%
# 4. Average pressure by Martian month
avg_pressure = df.groupby('month')['pressure'].mean()
avg_pressure
# Out:
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month
pressure_graph = avg_pressure.plot(kind = "bar")
pressure_graph.set_xlabel("month")
pressure_graph.set_ylabel("Atmospheric Pressure")
# Out:
# Text(0, 0.5, 'Atmospheric Pressure')

# %%
dates = df.groupby('terrestrial_date')['month'].mean()
dates
# Out:
# terrestrial_date
# 2012-08-16    6.0
# 2012-08-17    6.0
# 2012-08-18    6.0
# 2012-08-19    6.0
# 2012-08-20    6.0
#              ...
# 2018-02-23    5.0
# 2018-02-24    5.0
# 2018-02-25    5.0
# 2018-02-26    5.0
# 2018-02-27    5.0
# Name: month, Length: 1867, dtype: float64

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?
days = df.groupby('terrestrial_date')['month']
min_temp = df['min_temp']
days_graph = df.plot(kind = "scatter")
days_graph.set_xlabel("month")
days_graph.set_ylabel("Atmospheric Pressure")

plt.scatter(x=x,y=y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\racra\New folder\bootcamp\Homework\scraping-challenge\scraping-challenge\part_2_mars_weather.ipynb Cell 30 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/racra/New%20folder/bootcamp/Homework/scraping-challenge/scraping-challenge/part_2_mars_weather.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> days = df.groupby('terrestrial_date')['month']
#       <a href='vscode-notebook-cell:/c%3A/Users/racra/New%20folder/bootcamp/Homework/scraping-challenge/scraping-challenge/part_2_mars_weather.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> min_temp = df['min_temp']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/racra/New%20folder/bootcamp/Homework/scraping-challenge/scraping-challenge/part_2_mars_weather.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a> days_graph = df.plot(kind = "scatter")
# ...

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# The distance from peak to peak is roughly 1425-750, or 675 days. A year on Mars appears to be about 675 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
df.to_csv(mars_data.csv, encoding='utf-8', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\racra\New folder\bootcamp\Homework\scraping-challenge\scraping-challenge\part_2_mars_weather.ipynb Cell 35 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/racra/New%20folder/bootcamp/Homework/scraping-challenge/scraping-challenge/part_2_mars_weather.ipynb#X41sZmlsZQ%3D%3D?line=0'>1</a> # Write the data to a CSV
# ----> <a href='vscode-notebook-cell:/c%3A/Users/racra/New%20folder/bootcamp/Homework/scraping-challenge/scraping-challenge/part_2_mars_weather.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a> df.to_csv(mars_data.csv, encoding='utf-8', index=False)
#
# AttributeError: 'list' object has no attribute 'csv'

# %%
browser.quit()
